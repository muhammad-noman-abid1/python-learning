# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-noman-abid1/python-learning/blob/main/PROJECT_01_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT_01 .py **
# Snake,Water,Gun Game

# %%
'''
1 for snake
-1 for water
0 for gun
'''

computer = -1
you = int(input("Enter your choice"))
