# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-noman-abid1/python-learning/blob/main/PROJECT_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT_01 .py**
#
# Rock,Paper,Scissor game

# %%
'''
1 for rock
-1 for paper
0 for scissor
'''
import random  # random module imported so computer can choose random

computer = random.choice([1, -1, 0])

youstr = input("Enter your choice (rock,paper,scissor): ")
youDict = {"r":1,"p":-1,"s":0}
reverseDict = {1:"Rock",-1:"Paper",0:"Scissor"}

you = youDict[youstr]
# by now we have two numbers(vairables), you and computer

print(f"You choose: {reverseDict[you]} \nComputer choose: {reverseDict[computer]} ")

if(computer == you):  # if same of you and computer
  print("It's a draw!")
else:
  if(computer==-1 and you ==1): #-2  # you can say it a nested loop because i use if inside an if statment
   print("you lose!")

  elif(computer==1 and you ==-1): #2
    print("you win!")

  elif(computer==1 and you ==0):#1
    print("you lose!")

  elif(computer==0 and you ==1):#-1
    print("you win!")

  elif(computer==-1 and you ==0):#-1
    print("you win!")

  elif(computer==0 and you ==-1):#1
    print("you lose!")

  else:
    print("something went wrong!")
# Out:
# Enter your choice (rock,paper,scissor): r
# You choose: Rock
# Computer choose: Paper
# you lose!

# %% [markdown]
# Created the same game after analysing the pattern and using more efficient method but it reduce the readabiltiy of program

# %%
import random  # random module imported so computer can choose random

computer = random.choice([1, -1, 0])

youstr = input("Enter your choice (rock,paper,scissor): ")
youDict = {"r":1,"p":-1,"s":0}
reverseDict = {1:"Rock",-1:"Paper",0:"Scissor"}

you = youDict[youstr]
# by now we have two numbers(vairables), you and computer

print(f"You choose: {reverseDict[you]} \nComputer choose: {reverseDict[computer]} ")

if(computer == you):  # if same of you and computer
  print("It's a draw!")
if ((computer - you) == 1 or  (computer - you) == -2):
  print("You lose! ")
elif ((computer - you) == -1 or  (computer - you) == 2):
  print("You win!")
# Out:
# Enter your choice (rock,paper,scissor): p
# You choose: Paper
# Computer choose: Paper
# It's a draw!
