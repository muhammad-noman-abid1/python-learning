# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-noman-abid1/python-learning/blob/main/Chapter_09_File_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
a =  "a vey long string"

'''

# Create/overwrite file.txt and write content to it
with open("file.txt", "w") as f:
    f.write("Hello from file.txt!")

f = open("file.txt" )
data = f.read()
print(data)
f.close()
# Out:
# Hello from file.txt!

# %%
f = open("myfile.txt", "w")

f.write("Hello, I am learning Python File I/O.")

f.close()
